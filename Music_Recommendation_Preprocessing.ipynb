# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Setting up Kaggle directory and downloading dataset from Kaggle
#
# This is **[Spotify Music data to identify the moods](https://www.kaggle.com/datasets/musicblogger/spotify-music-data-to-identify-the-moods/data)**
#
# This has details of 686 songs with mood labelled to them.
#
# Moods are :
# + Sad
# + Happy
# + Calm
# + Energetic

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d musicblogger/spotify-music-data-to-identify-the-moods
# Out:
# ...
#   0% 0.00/56.0k [00:00<?, ?B/s]
# 100% 56.0k/56.0k [00:00<00:00, 51.4MB/s]

# %%
# !unzip /content/spotify-music-data-to-identify-the-moods.zip -d data
# Out:
# Archive:  /content/spotify-music-data-to-identify-the-moods.zip
#   inflating: data/data_moods.csv

# %% [markdown]
# # Importing Necessary Libraries and PreProcessing the data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/data_moods.csv')

# %%
df.head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              686 non-null    object
#  1   album             686 non-null    object
#  2   artist            686 non-null    object
#  3   id                686 non-null    object
#  4   release_date      686 non-null    object
#  5   popularity        686 non-null    int64
#  6   length            686 non-null    int64
#  7   danceability      686 non-null    float64
#  8   acousticness      686 non-null    float64
#  9   energy            686 non-null    float64
#  10  instrumentalness  686 non-null    float64
#  11  liveness          686 non-null    float64
#  12  valence           686 non-null    float64
#  13  loudness          686 non-null    float64
#  14  speechiness       686 non-null    float64
#  15  tempo             686 non-null    float64
# ...

# %%
df_new = df[['name','album','artist','id','popularity','mood']]
df_new
# Out:
#                                             name  \
# 0                                           1999
# 1                                             23
# 2                                       9 Crimes
# 3                                 99 Luftballons
# 4    A Boy Brushed Red Living In Black And White
# ..                                           ...
# 681                                  windcatcher
# 682              yellow is the color of her eyes
# 683                           you broke me first
# 684                          you were good to me
# 685                                         æfre
#
#                                album          artist                      id  \
# 0                               1999          Prince  2H7PHVdQ3mXqEHXcvclTB0
# 1                                 23  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP
# 2                                  9     Damien Rice  5GZEeowhvSieFDiR8fQ2im
# ...

# %%
df_new['mood'].value_counts()
# Out:
# mood
# Sad          197
# Calm         195
# Energetic    154
# Happy        140
# Name: count, dtype: int64

# %% [markdown]
# # Saving the dataset to a new csv file

# %%
df_new.to_csv('./drive/MyDrive/songs_mood.csv',index=False)
